# %% [markdown]
# ## Chapter 4
# ### XYZ Tiles
#
# **<u>Week 0. Introduction</u>**
#
# >- Installs GDAL to build the GeoTIFF rasters in XYZ tile format, which will be housed in your Linux virtual machine and displayed in later chapters on web development.
#
# >Prerequisites: Builds off the previous chapters information on command line.
#
# **<u>Week 1. GDAL Installation</u>**
#
# **Week 1 Homework: Proj Installation**
#
# <i>Grading Scale:</i>
#
# 0. Did not attempt.
# 1. Installed Proj from source.
#
# **Notes**
#
# >- At the turn of the millennium, the internet was painfully slow because of hardware and web based software restricting transmission rates in parts of the country that lacked physical infrastructure.
#
# >>- This made data transfer difficult.
#
# >>- It was not feasible to display large raster data files representing the Earth for use in the commercial sector.
#
# >>- File formats were designed to more efficiently serve the large aerial imagery as the end user requested the information.
#
# >>- The standard XYZ tile format accomplished the task by building several thousand compressed JPGs at different scales and sending the small kilobytes picture file sizes to the user rather than the entire gigabyte geoTIFF.
#
# >- There were several early internet mapping companies whose technology was eventually acquired by Google Maps, Yahoo Maps, etc.
#
# >- Early buyouts included nondisclosure agreements that restricted what could be said about the technology and literature inspired placeholders emerged online to avoid contractual legal barriers.
#
# >>- Mistrust and lack of understanding for network security lead to accusations of technology theft when in reality several groups of people were tought from the same education curriculum and had the ability to develop nearly identical software.
#
# >>- Some of the annoying software made its way through litigation into modern internet websites to protect copyrighted material under the guise of reducing mindless usage by behavior modification.
#
# >>- Non-parametric statistics used by publicaly available sociology studies are not able to accurately modify human behavior and are more likely to radicalize the victim to incite panic buying and former internet startups mirrored television, radio, and electricity companies.
#
# **Homework Notes**
#
# >- The first step to installing the version of GDAL with the required features is to install the Proj library.
#
# >>- Chapter 3 introduced the Proj library with the installation of Python methods.
#
# >>- Since the Earth is uniquely shaped, various mapping projections were developed to minimize distortion.
#
# >>- Since organizations are geographically located in different areas, they store their data in projections and the Proj C++ library handles recalculating coordinates.
#
# >- Use 'wget' to download 'proj-version' and unzip the package with the command 'tar' or 'unzip'.

# %%
# Install proj-<version>
cd /User/your_download_folder
wget https://download.osgeo.org/proj/proj-X.X.0.tar.gz
tar xvzf proj-X.X.0.tar.gz

# %% [markdown]
# >- Change directories and configure the project with proj specified as the folder path /usr/local.

# %%
cd proj-X.X.X
sudo ./configure --without-curl
sudo make
sudo make install

# %% [markdown]
# **<u>Week 2. GDAL Installation: Part 2 of 3</u>**
#
# **Week 1 Homework Due**
#
# **Week 2 Homework: GDAL Installation**
#
# <i>Grading Scale:</i>
#
# 0. Did not attempt.
# 1. Installed GDAL from source.
#
# **Homework Notes**
#
# >- Now that GDAL's dependency Proj has been installed, GDAL version 3.X can be installed.
#
# >-  Use 'wget' and 'unzip' to download GDAL and unzip it.

# %%
/User/your_download_folder
sudo wget download.osgeo.org/gdal/3.X.X/gdal3XX.zip
sudo unzip gdal3XX.zip

# %% [markdown]
# >- Configure with python3 and install with make. The && operator runs a command once the previous command has finished.

# %%
cd gdal-3.X.X
sudo ./configure -with-proj=/usr/local -with-python3
sudo make clean && sudo make && sudo make install

# %% [markdown]
# >- Export the LD_LIBRARY_PATH and enter the command 'ldconfig' after GDAL compiles.

# %%
export LD_LIBRARY_PATH=/usr/local/lib
sudo ldconfig

# %% [markdown]
# **<u>Week 3. GDAL Installation: Part 3 of 3</u>**
#
# >**Week 2 Homework Reminder**
#
# **<u>Week  4. RGB Text Files</u>**
#
# **Week 2 Homework Due**
#
# **Week 4 Homework: RGB Text**
#
# <i>Grading Scale:</i>
#
# 0. Did not attempt.
# 1. Creates RGB rasters.
#
# **Homework Notes**
#
# >- The second to last step is generating XYZ tiles for the raster outputs of the python script(s) for use in a web application.
#
# >- The process uses a GDAL command line tool called 'gdaldem color-relief' to apply a color scheme to the raster with a text file.
#
# >- The first column is the breaks while the other numbers are the color in Red, Green, Blue, Opacity (RGBA).
#
# >- The tool defaults opacity to 255 without specifying the value.
#
# >- An example .txt file using spaces as the seperators without the opacity layer specified looks like this:

# %%
0 0   0    0
1 200 221  240
2 115 179  216
3 40  121  185
4 8   48   107

# %% [markdown]
# >- An example command as described in the documentation:

# %%
sudo gdaldem color-relief <input_raster> <color_text_file> <output_color_relief_map> -alpha

# %% [markdown]
# **<u>Week 5. XYZ Tiles with GDAL: Part 1 of 2</u>**
#
# **Week 4 Homework Reminder**
#
# **Week 5 Homework: XYZ Tiles**
#
# <i>Grading Scale:</i>
#
# 0. Did not attempt.
# 1. Generates XYZ tiles.
#
# **Homework Notes**
#
# >- The output raster generated from the GDAL command line is used in the next step to generate the XYZ tiles with a GDAL python file.
#
# >- Below is an example command to generate an XYZ tile:

# %%
sudo gdal2tiles.py --zoom=2-8 --tilesize=128 <input_color_relief> <output_directory_name>

# %% [markdown]
# **<u>Week 6. Review for Midterm</u>**
#
# >**Week 4 Homework Due**
#
# >**Week 5 Homework Reminder**
#
# **<u>Week 7. Midterm</u>**
#
# >**Week 5 Homework Reminder**
#
# **<u>Week 8. XYZ Tiles with GDAL: Part 2 of 2</u>**
#
# >**Week 5 Homework Reminder**
#
# **<u>Week 9. Automating XYZ Tiles: Part 1 of 3</u>**
#
# **Week 5 Homework Due**
#
# **Week 9 Homework: BASH XYZ Tiles**
#
# <i>Grading Scale:</i>
#
# 0. Did not attempt.
# 1. Generates XYZ Tiles.
#
# **Homework Notes**
#
# >- The goal of this week is to develop a BASH program that automates the download, extraction, and display of rasters.
#
# >- This section uses command line scripting in the BASH language (file.sh) to automate the transformation of several times series rasters to XYZ tiles.
#
# >- The first step is to set a variable to point toward the folder containing the several .tiff files.
#
# >>- <i>VARIABLENAME</i> was defined in Chapter 3 as the working directory of the project.

# %%
VARIABLENAME="/User/<name>/linux_project/data"
PROJECT_TIFFS=$VARIABLENAME"/data/tiffs"

# %% [markdown]
# >- The .txt color scheme as described in the previous week.

# %%
PROJECT_TIFFS_COLOR=$VARIABLENAME"/data/final_color.txt"

# %% [markdown]
# >- A variable named <i>COLOR</i> is used to concatenate an ending onto the output files from the GDAL command.

# %%
COLOR="_color.tif"

# %% [markdown]
# >- Another variable holds the base for more concatenation.

# %%
PROJECT_XYZ_BASE="/linux_project/data/tiffs"

# %% [markdown]
# >- Loop over the list of rasters defined by <i>PROJECT_TIFFS</i> and set an increment variable for the year. Each raster file path is represented by the <i>data</i> variable.
#
# >>- The example raster years range from 1981-2014.
#
# >>- The variable <i>project_color_output</i> is defined as a string to hold the ouput of the 'color-relief' tool that is run later in the loop.
#
# >>>- Each tiff without the file extension is defined as a string by using the operator %% to get all the characters before the '.' and file path.
#
# >>>- The wildcard * operator follows the '.' to include any spelling variation of '.tiff' extension.
#
# >>>- The tiff name is concatenated with "_color.tif" from the <i>COLOR</i> variable to differentiate it from the greyscale rasters.

# %%
increment=1981
for data in "$PROJECT_TIFFS"/*_reclassed.tif
do
  project_color_output=${data%%.*}$COLOR

# %% [markdown]
# >- Continuing within the for loop, another variable is declared to hold the output of the XYZ tool incrementing each year.

# %%
increment=1981
for data in "$PROJECT_TIFFS"/*_reclassed.tif
do
  project_color_output=${tiffs%%.*}$COLOR

  # Variable
  project_xyz_output=$PROJECT_XYZ_BASE$increment

# %% [markdown]
# >- Run the 'color-relief' command for each of the time periods.

# %%
increment=1981
for data in "$PROJECT_TIFFS"/*your_tiff_file_name.tif
do
    # Output variable names
    project_color_output=${data%%.*}$COLOR
    project_xyz_output=$PROJECT_XYZ_BASE$increment

    # Command to run the color-relief tool.
    sudo gdaldem color-relief $data $PROJECT_TIFFS_COLOR $project_color_output -alpha

# %% [markdown]
# >- The Python command generates a folder of XYZ tiles for each raster at the specified zoom and resolution.

# %%
# Loop over ppt_bil2tif_resize
# Concatenate _color.tif to the output
# build color ramp and xyz tiles

increment=1981
for data in "$PROJECT_TIFFS"/*your_tiff_file_name.tif
do
    # Output variable names
    project_color_output=${data%%.*}$COLOR
    project_xyz_output=$PROJECT_XYZ_BASE$increment
    # Command to run the color-relief tool.
    sudo gdaldem color-relief $data $PROJECT_TIFFS_COLOR $project_color_output -alpha

    # Python script to generate the XYZ tiles.
    sudo gdal2tiles.py --zoom=2-8 --tilesize=128 $project_color_output $project_xyz_output

# %% [markdown]
# >- The final step increments the year but the string can be replaced with any unit of time. The completed program includes 'echo' statements to print relevant text to the command output while testing.

# %%
# Loop over ppt_bil2tif_resize
# Concatenate _color.tif to the output
# Build color ramp and xyz tiles

increment=1981
for data in "$PROJECT_TIFFS"/*_file_ending.tif
do
    # Output variable names
    project_color_output=${data%%.*}$COLOR
    project_xyz_output=$PROJECT_XYZ_BASE$increment

    sudo gdaldem color-relief $data $PROJECT_TIFFS_COLOR $project_color_output -alpha

    echo "Color tif for year "$increment

    sudo gdal2tiles.py --zoom=2-8 --tilesize=128 $project_color_output $project_xyz_output

    echo "xyz tiles for year"$increment

  increment=$((increment+1))

  if [[ $increment -eq 2015 ]];
  then
    break
  fi
done

# %% [markdown]
# **<u>Week 10. Automating XYZ Tiles: Part 2 of 3</u>**
#
# **Week 9 Homework Reminder**
#
# **Homework Notes**
#
# >- It is worth mentioning that the tiff file naming convention is important for the .sh to run correctly.
#
# >- The example folder of tiffs looks like:

# %%
~/tiff/2024_hillslope_file_ending.tif
~/tiff/2023_hillslope_file_ending.tif
~/tiff/2022_hillslope_file_ending.tif
~/tiff/2021_hillslope_file_ending.tif

# %% [markdown]
# **<u>Week 11. Automating XYZ Tiles: Part 3 of 3</u>**
#
# >**Week 9 Homework Reminder**
#
# **<u>Week 12. BASH Automation: Part 1 of 4</u>**
#
# >**Week 9 Homework Due**
#
# **Week 12 Homework: BASH Automation**
#
# <i>Grading Scale:</i>
#
# 0. Did not attempt.
# 1. Installs Python, runs scripts, and generates XYZ tiles.
#
# **<u>Week 13. BASH Automation: Part 2 of 4</u>**
#
# >**Week 12 Homework Reminder**
#
# **<u>Week 14. BASH Automation: Part 3 of 4</u>**
#
# >**Week 12 Homework Reminder**
#
# **<u>Week 15. BASH Automation: Part 4 of 4</u>**
#
# **Week 12 Homework Reminder**
#
# >- The joke is that doing all this is impossible because the script will break while installing Proj and GDAL automatically, making it more difficult to make a mapping virus that gives bad directions.
#
# >- However, it is possible to install all of the libraries manually and is a good learning exercise in how to design a database or operating system.
#
# **<u>Week 16. Final Review</u>**
#
# >**Week 12 Homework Due**
#
# **<u>Week 17. Final</u>**
