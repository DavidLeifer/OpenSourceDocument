# %% [markdown]
# ## Chapter 3
#
# ### Linux Automation
#
# **<u>Week 0. Introduction</u>**
#
# >- Describes how to use the command line to install several Python libraries to download rasters and perform calculations.
#
# >- Chapter 4 directly builds off this chapter by using the GDAL XYZ tile tool and automating the process with BASH.
#
# >Prerequisites: Command line basics and programming skills to learn BASH.
#
# **<u>Week 1. Installing Apache Server</u>**
#
# **Week 1 Homework: Apache Server**
#
# <i>Grading Scale:</i>
#
# 0. Did not attempt.
# 1. Installed Apache Server.
#
# **Notes**
#
# >- Apache Server is an open source web server.
#
# >- It is a default server when starting a Google Cloud Platform instance with Debian or Ubuntu.
#
# >>- If you were to follow these steps on a cloud provider, the information would be available at the instances IP address.
#
# >- This course will continue using a Linux OS image in a Virtual Box to display the web development information on the local machine.
#
# >- Enter the command to update Linux and install apache2. The -y flag automatically tells the the utility apt to enter yes at the required prompt.

# %%
sudo apt update
sudo apt upgrade
sudo apt install apache2 -y

# %% [markdown]
# >- This is an optional step that is not required for localhost but would allow the installation of HTTPS certificates in a production environment.

# %%
sudo a2ensite default-ssl
sudo a2enmod ssl

# %% [markdown]
# >- Pointing a web browser to localhost would reveal a basic text page. The HTML can be modified in the index file at this location:

# %%
/var/www/html/index.html

# %% [markdown]
# **<u>Week 2. Data Management</u>**
#
# **Week 1 Homework Due**
#
# **Week 2 Homework: Data Management**
#
# <i>Grading Scale:</i>
#
# 0. Did not attempt.
# 1. Downloaded data and created the directory.
# 2. Used WGET or Python to download data to the local web server.
#
# **Notes**
#
# >- The open source Geospatial Data Abstraction Library (GDAL) provides several Python, C++, and command line tools that are similar to ESRI functions.
#
# >- One such tool converts geoTIFFS to XYZ files.
#
# >- This tool will be installed in the next chapter but there are several data management steps necessary to write the automated BASH file.
#
# >- The idea is to eventually have all the data and Python files in one location and referenced in a .sh file that will be run when the user is in the directory.
#
# **Homework Notes**
#
# >- The first step is to choose a project and is usually dictated by the availability of data.
#
# >>- One place to acquire publically available geoTIFFS is the United States Geological (USGS) Earth Explorer.
#
# >>>- Digital elevation maps for erosion monitoring, surface runoff, and line of sight.
#
# >>>- LandSat imagery for land use or land cover prediction equations.
#
# >>- Another source is the National Oceanic and Atmospheric Administration (NOAA) Digital Coast website.
#
# >>>- Elevation maps for sea level rise, landslides, or gradual coast line erosion.
#
# >>>- Imagery from hurricane damage.
#
# >>- USGS Upper Mississippi Environmental Sciences Center.
#
# >>>- Bathymetric data for river current estimation.
#
# >- Other regional, state, or local sources such as the Department of Natural Resources (DNR) that might have additional imagery, parcel, or topographic maps.
#
# >- The next step is to download timeseries rasters from your source with 'wget'.
#
# >- Another download option is to use the Python library 'url.request' or install the 'request' library to download HTML.
#
# >>- The HTML can be parsed manually or with BeautifulSoup or 'lxml'.
#
# >>- This makes handling bulk file downloads from dynamic pages easier and has more examples for novice programmers.

# %%
sudo apt install wget
wget <https_URL_to_your_download>

# %% [markdown]
# >- The command line tool 'mkdir' creates several folders on the web server to store the output XYZ files from the GDAL commands.
#
# >- In a production environment, you would use a Database for increased security and features but since the data is already available on the internet it can be used to learn the technology of how to display tiles.

# %%
sudo mkdir /var/www/html/<name_of_your_data>/

# %% [markdown]
# **<u>Week 3. Installing Python: Part 1 of 3</u>**
#
# **Week 2 Homework Due**
#
# **Week 3 Homework: Installing Python**
#
# <i>Grading Scale:</i>
#
# 0. Did not attempt.
# 1. Installs 'python3' with 'pip3'.
#
# **Homework Notes**
#
# >- The next few weeks will be spent downloading and installing Python.
#
# >- There are several dependency issues with the command line tool GDAL and the associated GDAL Python bindings.
#
# >- A semi-manual build is required to get the libraries working. Replace VERSION with the necessary Python version.

# %%
# Libraries for installing python
sudo apt install libcurl<VERSION>-openssl-dev libssl-dev
sudo apt install python3-pip

# Adds an additional repository for Ubuntu GIS command line tools
sudo add-apt-repository -y ppa:ubuntugis/ubuntugis-unstable

# More C++ tools are needed to install GIS libraries
sudo apt install sqlite3
sudo apt install libsqlite3-dev
sudo apt install -y libtiff<VERSION>-dev

# %% [markdown]
# >- You may have to remove 'python-gdal' (or any package) at some point and reinstall.
#
# >- The commands 'purge' and 'autoremove' assist in removing unwanted configuration and libraries automatically installed.

# %%
# sudo apt remove python-gdal

# %% [markdown]
# >- Geopandas has additional C dependencies.

# %%
# Install 'geopandas'
sudo apt install libspatialindex-dev

# %% [markdown]
# **<u>Week 4. Installing Python: Part 2 of 3</u>**
#
# >**Week 3 Homework Reminder**
#
# **<u>Week 5. Installing Python: Part 3 of 3</u>**
#
# >**Week 3 Homework Due**
#
# **<u>Week 6. Review for Midterm</u>**
#
# **<u>Week 7. Midterm</u>**
#
# **<u>Week 8. Installing Python Libraries: Part 1 of 3</u>**
#
# **Week 8 Homework: Installing Python Libraries**
#
# <i>Grading Scale:</i>
#
# 0. Did not attempt.
# 1. Installs Python 3.X Libraries.
#
# **Homework Notes**
#
# >- The first step is to use 'pip3' to upgrade 'pip'.

# %%
sudo pip3 install --upgrade pip

# %% [markdown]
# >- Install 'rasterio', a library to read and write raster data such as GeoTIFFS.

# %%
sudo pip3 install rasterio

# %% [markdown]
# >- Install pyproj, fiona, and geopandas to handle interfacing with the C++ library Proj, reading and writing vector data, and performing common geographic functions.

# %%
sudo pip3 install pyproj
sudo pip3 install fiona
sudo pip3 install geopandas

# %% [markdown]
# >- The final libraries to install include rtree for handling geographic indexing, pandas for tabular spreadsheets, and the GDAL wrapper for Python.

# %%
sudo pip3 install rtree
sudo pip3 install pandas==2.X.X
sudo pip3 install gdal==3.X.X

# %% [markdown]
# **<u>Week 9. Installing Python Libraries: Part 2 of 3</u>**
#
# >**Week 8 Homework Reminder**
#
# **<u>Week 10. Installing Python Libraries: Part 3 of 3</u>**
#
# >**Week 8 Homework Reminder**
#
# **<u>Week 11. Python Programming: Part 1 of 3</u>**
#
# **Week 8 Homework Due**
#
# **Week 11 Homework: Python Programming**
#
# <i>Grading Scale:</i>
#
# 0. Did not attempt.
# 1. Writes a Python script to perform a GIS function.
# 2. Implements a statistical function in Python.
# 3. Implements several geographic statistics in Python.
#
# **Homework Notes**
#
# >- This week is open ended. There are several examples on reading, writing, and programming with the previous week's libraries available on GitHub and in their documentation.
#
# >- Basic examples of statistical functions include mean, median, and regression.
#
# >- More complicated geographic statistics include moving correlation windows, Moran's I, or Analysis of Variance (ANOVA).
#
# **<u>Week 12. Python Programming: Part 2 of 3</u>**
#
# >**Week 11 Homework Reminder**
#
# **<u>Week 13. Python Programming: Part 3 of 3</u>**
#
# >**Week 11 Homework Reminder**
#
# **<u>Week 14. BASH Python Scripts: Part 1 of 2</u>**
#
# **Week 11 Homework Due**
#
# **Week 14 Homework: BASH Programming**
#
# <i>Grading Scale:</i>
#
# 0. Did not attempt.
# 1. Automatically runs the Python script(s) with BASH.
#
# **Homework Notes**
#
# >- This week will cover automating the execution of Python scripts by using BASH.
#
# >- A common feature of open source projects is that the repository can be downloaded with 'git' and installed from the command line.
#
# >- The first step is to create paths of the directory the project is located in.

# %%
DATA_PATH=$(pwd)
export VARIABLENAME=$DATA_PATH

# %% [markdown]
# >- To organize the project more effectively, create a subfolder named /python/ within the current directory.
#
# >- An example folder path to house the .py files might be:

# %%
/User/<name>/linux_project/python/

# %% [markdown]
# >- The next command is a simple addition of two text strings.

# %%
PYTHON_FILE_NAME="$VARIABLENAME/python/python_GIS_analysis.py"

# %% [markdown]
# >- The final step is to run the program.

# %%
sudo python3 $PYTHON_FILE

# %% [markdown]
# **<u>Week 15. BASH Python Scripts: Part 2 of 2</u>**
#
# >**<u>Week 14 Homework Reminder**
#
# **<u>Week 16. Review for Final</u>**
#
# >**Week 14 Homework Due**
#
# **<u>Week 17. Final</u>**
