# %% [markdown]
# ## Chapter 10
# ### Data Visualization
#
# **<u> Week 0. Introduction</u>**
#
# >- The goal of this chapter is to combine computer science and data visualization techniques by writing a time series graph in text.
#
# >- There are several examples that exist in Python already: matplotlib, Plotly, seaborn, etc.
#
# > Prerequisites: This course builds off previous chapter's on reading input data and performing descriptive statistics.
#
# **<u> Week 1. Highest and Lowest Number Part 1 of 3 </u>**
#
# **Week 1 Homework: Highest and Lowest**
#
# >- Make a new class 'Graph' and a function 'hi_lo' that returns the highest number and lowest number from a list of numbers.
#
# <i>Grading Scale:</i>
#
# 0. Did not attempt
# 1. Function calculates the highest number
# 2. Function calculates the highest and the lowest number
#
# >- Finding the lowest and highest number is a basic algorithm that can be accomplished in a time complexity of O(n) and auxiliary space O(1).
#
# >- One method is to sort the list and return the first and last value of the list. Time complexity is O(n log n).
#
# **<u> Week 2. Highest and Lowest Number Part 2 of 3 </u>**
#
# **Week 1 Homework Reminder**
#
# >- Another method is linear search, which sets the high and low number and replaces the values by comparison in a loop. Time complexity is 0(n).
#
# **<u> Week 3. Highest and Lowest Number Part 3 of 3 </u>**
#
# **Week 1 Homework Reminder**
#
# >- Other methods include the tournament selection approach which divides the dataset into two parts but increases auxiliary space to O(log n).
#
# >- Pairwise comparison is the same speed and space as linear search.
#
# **<u> Week 4. Data Binning Part 1 of 3 </u>**
#
# **Week 1 Homework Due**
#
# **Week 1 Homework example**

# %%
##############################################
# Data visualization with a timeseries graph #
##############################################
# 'Graph' class accepts three variables: verticle arranged 'data',
# the date column'date_col_num', and the data column 'data_col_num'
class Graph:
  # Initialize the input variables
  def __init__(self, data, date_col_num, data_col_num):
    self.data = data
    self.date_col_num = date_col_num
    self.data_col_num = data_col_num
  def hi_lo(self, data_col_num):
    # The date and date column to be used
    data_col = self.data[data_col_num]
    data_col_len = len(data_col)
    # High and low of values
    hi_lo_count = 1
    hi = data_col[1]
    lo = data_col[1]
    for i in range(len(data_col[1:])):
      hi_lo_count += 1
      if hi_lo_count == (len(data_col[1:]) + 1):
        break
      if hi < data_col[hi_lo_count]:
        hi = data_col[hi_lo_count]
      if lo > data_col[hi_lo_count]:
        lo = data_col[hi_lo_count]
    return [hi, lo]

# %% [markdown]
# **Week 4 Homework: Data Binning**
#
# >- Make a function called 'binned' that accepts a list of numbers and the output from 'hi_lo' and returns the data into binned categories.
#
# <i>Grading Scale:</i>
#
# 0. Did not attempt
# 1. Returns a list of lists of binned data from 1 to 5.
# 2. Returns a list of lists of binned data for any data range.
#
# **<u> Week 5. Data Binning Part 2 of 2 </u>**
#
# **Week 4 Homework Reminder**
#
# >- The goal for this function is to bin the datapoints with the date for use in another function.
#
# >- The next function will count the spaces between each value for printing purposes.
#
# **<u> Week 6. Review for midterm </u>**
#
# **Week 4 Homework Due**
#
# **Week 4 Homework Example:**

# %%
def binned(self, hi_lo):
  # high value (5 in this case or hi_lo[0])
  # The date and date column to be used
  # TODO it works but is not resuable for other data ranges
  date_col = self.data[self.date_col_num]
  data_col = self.data[self.data_col_num]
  data_col_len = len(data_col)
  fiver = []
  fourer = []
  threer = []
  twoer = []
  oner = []
  lol_stm_date = []
  counter = 1
  # Binned with date value
  for i in range(data_col_len):
    P0_column = self.data[self.data_col_num]
    if counter == len(self.data[0]):
      break
    if float(P0_column[counter]) == 5:
      fiver.append([date_col[counter], P0_column[counter]])
    elif float(P0_column[counter]) == 4:
      fourer.append([date_col[counter], P0_column[counter]])
    elif float(P0_column[counter]) == 3:
      threer.append([date_col[counter], P0_column[counter]])
    elif float(P0_column[counter]) == 2:
      twoer.append([date_col[counter], P0_column[counter]])
    elif float(P0_column[counter]) == 1:
      oner.append([date_col[counter], P0_column[counter]])
    counter += 1
  # Combining the binned data into one dictionary
  lol_date_stm = [fiver, fourer, threer, twoer, oner]
  return lol_date_stm

# %% [markdown]
# >- Another method would be to replace the 5,4,3,2,1 equivilency value if/else statements with one if/else statement and an iterator through the 'hi' and 'lo' values. The code would be more reusable.
#
# **<u> Week 7. Midterm </u>**
#
# </br>
#
# **<u> Week 8. Break </u>**
#
# </br>
#
# **<u> Week 9. Time Series Part 1 of 3 </u>**
#
# **Week 9 Homework: Time Series**
#
# >- Make a function called 'time_series' that accepts the output from 'hi_lo' and 'binned' that returns the spaces neccessary to print an X and Y axis along with the spaces between each data point denoted by a mark '+'.
#
# The eventual output:
#
# ![GraphExample.jpg](/Chapter10/GraphExample.jpg)
#
# >- This function is only looking for the spaces. Week 12 and week 15 functions will be printing the graph and saving the ouput as an image.
#
# <i>Grading Scale:</i>
#
# 0. Did not attempt
# 1. Returns the spaces between each data point
# 2. Returns the spaces between each data point and a logical Y-axis step (i.e. 1-5 instead of 2-5 since there are no '1' values)
#
# **<u> Week 10. Time Series Part 2 of 3 </u>**
#
# **Week 9 Homework Reminder**
#
# >- The goal of this function is to return the spaces between data values.
#
# >- It is also neccessary to keep track of the y values which will assist in formatting the graph.
#
# **<u> Week 11. Time Series Part 3 of 3 </u>**
#
# >- The time series graph is a very basic black and white image without any stylistic design considerations other than displaying the information requested.
#
# >>- There are several graphing libraries already available as listed before but they all make use of the externally maintained Python Image Library (PIL) for RGB writing.
#
# >>- Writing an image encoder/decoder and a video driver requires C and hardware knowledge that is beyond the scope of this course.
#
# >- One point of this class is to shed light on the statistical techniques employed by business marketing.
#
# >>- On an individual level, avoiding purchasing unnecessary items increases financial freedom.
#
# >>- On a macro scale, avoiding wasteful purchases on disposable goods helps the planet.
#
# >>>- Runaway consumerism has several well documented environmental issues besides anthropogenic climate change.
#
# >>>- Examples include air and ocean pollution from waste disposal methods like burning or dumping trash.
#
# **<u> Week 12. Print Graph Part 1 of 3 </u>**
#
# **Week 9 Homework Due**
#
# **Week 9 Homework Example:**

# %%
def time_series(self, date_hi_lo, lol_date_stm):
  # Base of the month, plus 00 i.e. 500
  date_base = int(date_hi_lo[1]) - 1
  # The number of spaces is the 'day' (date - month) - 'prev_day_space_int'
  # The difference between the values is multiplied by ' ' for each 5,4,3,2,1
  # Value with a '+' character marking the position
  spacer = []
  prev_day_space_int = 0
  for i in lol_date_stm:
    spacer_mid = []
    for j in i:
      day = int(j[0]) - date_base
      day_count = day - prev_day_space_int
      day_space_str = ((day_count-1)*2) * " "
      spacer_mid.append(day_space_str)
      prev_day_space_int = day
    prev_day_space_int = 0
    spacer.append(spacer_mid)
  y_val = [y for y in range(len(spacer),0,-1)]
  return [spacer, y_val]

# %% [markdown]
# **Week 12 Homework: Print Graph**
#
# >- Make a function called 'time_series_print' that prints the graphs into the console.
#
# >- The input to the function accepts the 'spacer' and 'y_val' from the previous function in Week 9.
#
# >- It operates similar to a printer or writing a document by hand in English from left to right and top to bottom.
#
# **Example output:**
#
# ![GraphExample.jpg](/Chapter10/GraphExample.jpg)
#
# <i>Grading Scale:</i>
#
# 0. Did not attempt
# 1. Prints the graph
#
# **<u> Week 13. Print Graph Part 2 of 3</u>**
#
# >**Week 12 Homework Reminder**
#
# **<u> Week 14. Print Graph Part 3 of 3</u>**
#
# >**Week 12 Homework Reminder**
#
# **<u> Week 15. Save Graph</u>**
#
# **Week 12 Homework Due**
#
# **Week 12 Homework Example:**

# %%
def time_series_print(self,spacer,y_val):
    date_col = self.data[self.date_col_num]
    for i,j in zip(spacer,y_val):
      # y values
      print(j,end=" ")
      for k in i:
        print(k,end="")
        print("+",end=" ")
      print()
    # x values
    for m in range(len(date_col[0])-1):
      print("  ",end="")
      for n in date_col[1:]:
        print(n[m],end=" ")
      print()
    return

# %% [markdown]
# **Week 15 Homework: Save Graph**
#
# >- Make a function called 'time_series_write' that saves the graphs from the previous function as an image.
#
# >- The function is nearly identical to the print function, except the Python library's default 'write' method uses '\n' to denote line breaks instead of relying on the default 'print' methods.
#
# **Example output:**
#
# ![GraphExample.jpg](/Chapter10/GraphExample.jpg)
#
# <i>Grading Scale:</i>
#
# 0. Did not attempt
# 1. Saves the graphs
#
# **<u> Week 16. Review for final</u>**
#
# **Week 15 Homework Due**
#
# **Week 15 Homework Example:**

# %%
def time_series_write(self,header,txt_out,spacer,y_val):
    # Open the output file location and write data to the txt
    date_col = self.data[self.date_col_num]
    file_output = open(txt_out, "w")
    file_output.write(header)
    file_output.write("\n")
    file_output.write("\n")
    # y values
    for j,k in zip(spacer,y_val):
      file_output.write(str(k) + " ")
      for l in j:
        file_output.write(str(l))
        file_output.write("+" + " ")
      file_output.write("\n")
    # x values
    for m in range(len(date_col[0])-1):
      file_output.write("  ")
      for n in date_col[1:]:
        file_output.write(str(n[m]) + " ")
      file_output.write("\n")
    file_output.close()
    return

# %% [markdown]
# **<u> Week 17. Final</u>**
