# %% [markdown]
# ## Chapter 2
#
# ### Time Series Rasters for Geoserver
#
# **<u>Week 0. Introduction</u>**
#
# >- This chapter installs Geoserver on Linux to display time series raster data.
#
# > Prerequisites: Basic understanding of computers.
#
# **<u>Week 1. Navigating a command line.</u>**
#
# **Week 1 Homework: Command Line**
#
# <i>Grading Scale:</i>
#
# 0. Did not attempt.
# 1. Creates a subfolder named /user/test/ and file named /user/test/hello_world.py
# 2. Writes and runs the "hello_world.py" file to print "Hello World!"
#
# **Homework Notes**
#
# >- From an operating system (OS) such as Windows, MacOS, or Linux, a text based command line interface can be used to access almost all of the OS folders and files, along with the user's files.
#
# >- Many of the system files are written in Assembly, C, or C++ and are inaccessible without administrator privileges.
#
# >- User file examples include pictures, movies, or text documents.
#
# >- It is highly recommended that you use a Virtual Machine (VM) like Oracle's application Virtual Box to boot a separate OS and avoid deleting your files or corrupting your boot drive. Backup your important files in a few different locations.
#
# >>- To use Linux from Windows or MacOS, you can boot from a virtual machine (VM) like Oracle's Virtual Box by downloading both the VM and a Linux OS image from their official websites.
#
# >>- Examples of Linux OS that are supported financially by private industries and branches of the government include Ubuntu or Debian.
#
# >- DO NOT root your phone to install third party command line applications.
#
# >- As described in Chapter 0, a Linux iamge can be accessed by signing up for a limited free cloud provider such as Google Cloud Platform (GCP) or Amazon Web Services (AWS).
#
# >- The least expensive option long term is to purchase a computer board like RaspberryPi or Adreno, which range in price from $15-70 and has more than enough CPU to learn command line work. Unless you get 8GB of RAM, these boards have difficulty running video playing websites.
#
# **More Homework Notes: Folder Navigation**
#
# >- These OS have filesystems that resemble branching tree structures. Below are a list of commands that are used to navigate the text based command line in Ubuntu and can be found on W3 Schools or in the Ubuntu documentation.

# %%
'''
Command	             Description
ls	                 List the folder (directory) contents.
cd /path 	           Change directory.
cd ..	               Move up one directory.
mv                   Move file to another directory.
mkdir	               Creates a new directory.
rmdir	               Remove a directory.
exit	               Closes the Terminal application.
man <command>	       Shows the manual for a given command.
<command> --h        Shows the help page for a command.
'''

# %% [markdown]
# **<u>Week 2. Managing User Permissions</u>**
#
# **Week 1 Homework Reminder**
#
# **Notes**
#
# >- Permission for a file is defined as users who can read, write, or execute a file or directory.
#
# >- Most retail devices connected to the internet can be logged into from other computers using the ssh (secure shell) protocol.
#
# >>- If someone guesses your password to access your computer, they could install a virus or gather other personal data.
#
# >>>- Information can be as benign as frequently used words from messaging applications used to mimic friends and family members or guess passwords.
#
# >>>- At the time of this writing, brute force password guessing programs can succeed on most alphanumeric strings under 13 characters in a reasonable amount of time.
#
# >>>- It is also possible to scrape trivial information from publicly available social media profiles to feed equations that guess the victim's online content and modify behavior to radicalize the person into panic shopping or other knee-jerk reactions.
#
# >>- Some programs on the internet are automated and have no owner, making it impossible for retribution or to stop since the program jumps from device to device.
#
# >>- One comparison is that the programs are similar to the flu virus, however it is important to not think entirely in similes and confuse a computer virus with the SARS-CoV-2 virus that was in the news recently.
#
# >- Hopefully this course will shed light to not fall for automated nonsense.
#
# **Homework Notes**
#
# >- Below is a list of permission related commands and includes only the basics. Read the official documentation if you have more questions. AI and websites similar to StackOverflow and Wikipedia are great for gathering ideas but it is important to double check a more reliable source.
#
# >- List permissions of a file or directory:

# %%
ls-l

# %% [markdown]
# >- Allow the user of a file to read and write:

# %%
chmod u+rw /file.py

# %% [markdown]
# >- The first letter of the command is the user or group:

# %%
'''
User                                       Letter

The user who owns the file or directory.   u
Other users in the file's group.           g
Other users not in the file's group.       o
All users.                                 a
'''

# %% [markdown]
# >- The '+' or '-' sign adds or subtracts a permission. Command line permissions can be represented by a letter or number:

# %%
'''
Command Explanation                       Letter    Number

Read                                      r         4
Write                                     w         2
Execute                                   x         1
'''

# %% [markdown]
# >- Command to change the ownership of all the files and directories in a directory where -R is a flag and sudo temporarily gives root access to the user without requiring the root password:

# %%
sudo chown -R <usrname>:<group> /the/directory/

# %% [markdown]
# >- Other flags can be added to modify the command:

# %%
'''
Flag Explanation                          Flag

Apply to all elements in directory.       R
Set user or group ID on execution.        s
Restricted deletion flag.                 t
The permissions for a user.               u
The permissions for other users.          g
Permissions for users not in the group.   o
'''

# %% [markdown]
# **<u>Week 3. Installing OpenJDK and Tomcat9: Part 1 of 4</u>**
#
# **Week 1 Homework Due**
#
# **Week 3 Homework: OpenJDK and Tomcat9 Install**
#
# <i>Grading Scale:</i>
#
# 0. Did not attempt.
# 1. Installed OpenJDK.
# 2. Installed OpenJDK and Tomcat9.
# 3. Installed the packages and configured Tomcat9 admin.
#
# **Homework Notes**
#
# >- The complexities of describing multidimensional data is challenging. One example of this effect is time series climatology data. By the time the basic information is summarized for the layperson, all meaning is binned into loaded terms with preconceived assumptions.
#
# >- The next few chapters include general instructions to install Geoserver on Linux to display raster time series data.
#
# >>- These steps were tested years ago with Tomcat8 which is a deprecated and unsupported web server library.
#
# >>- Installation could also occur on a live server with a cloud provider such as Google Cloud Platform or Amazon Web Services.
#
# >- The first step is to install Java 11 or 17 and Tomcat9 for the servlet container which will eventually house the "geoserver.war" file.

# %%
sudo apt update
sudo apt upgrade
sudo apt install openjdk-jdk

# %% [markdown]
# >- Check to see if the correct Java version was installed:

# %%
java -version

# %% [markdown]
# >- If the correct version of Java is not installed, you might have to download the binaries from the OpenJDK website and run the installation steps.
#
# >- To download Tomcat version 9, point your browser to the official website and navigate to the  binaries. Download the compressed file and move it to your user's directory either with the folder application or with a command:

# %%
mv /User/Downloads/apache-tomcat[version] /User/tomcat9/apache-tomcat[version]

# %% [markdown]
# >- Alternatively you can download from the command line with 'wget':

# %%
sudo wget <tomcat9_download_url_apache-tomcat[version]>

# %% [markdown]
# >- Install the 'unzip' utility if it is not already installed or use the file maanger to unzip the downloaded GeoServer files:

# %%
sudo apt install unzip

# %% [markdown]
# >- Unzip the package:

# %%
unzip /User/tomcat9/apache-tomcat[version]

# %% [markdown]
# >- Run the installation script. The full building commands can be found on the Tomcat GitHub or website.
#
# >- If you want to start, stop, or restart the servlet container, use the command below:

# %%
sudo systemctl start tomcat9
sudo systemctl stop tomcat9
sudo systemctl restart tomcat9

# %% [markdown]
# **<u>Week 4 Installing OpenJDK and Tomcat9: Part 2 of 4</u>**
#
# >**Week 3 Homework Reminder**
#
# **<u>Week 5. Installing OpenJDK and Tomcat9: Part 3 of 4</u>**
#
# >**Week 3 Homework Reminder**
#
# **<u>Week 6. Review for midterm</u>**
#
# >**Week 3 Homework Reminder**
#
# **<u>Week 7. Midterm</u>**
#
# >**Week 3 Homework Reminder**
#
# **<u>Week 8. Installing OpenJDK and Tomcat9: Part 4 of 4</u>**
#
# >**Week 3 Homework Reminder**
#
# **Homework Notes**
#
# >- Tomcat has a default user and password which means that if the server is deployed to the internet, anyone can access the information on the account.
#
# >- To configure the GUI and change the default settings, open up “tomcat-users.xml” with a command.

# %%
sudo nano /var/lib/tomcat9/conf/tomcat-users.xml

# %% [markdown]
# >- Add the following lines replacing <i>password</i> with your password and <i>username</i> with your username:

# %%
<role rolename="manager-gui"/>
<role rolename="admin-gui"/>
<user username="username" password="password" roles="manager-gui,admin-gui"/>

# %% [markdown]
# >- Save the file and restart Tomcat:

# %%
sudo systemctl restart tomcat9

# %% [markdown]
# >- Point the browser to the localhost at port 8080:

# %%
http://localhost:8080/

http://127.0.0.1:8080/

# %% [markdown]
# >- This is running only on your computer and is not connected to the internet.
#
# >- The IP address or domain name of a live server is used in a production environment.
#
# >- Live servers are more complicated because you need to include certificates to encrypt the information.
#
# >- http: Hyper Text Transfer Protocol
#
# >>- No encryption. The server can access your device.
#
# >- https: Hyper Text Transfer Protocol Secure
#
# >>- Encrypts the communication between the browser and the server and uses a certificate system to ensure text packages are not modified.
#
# >- Automated programs can modify unencrpyted web pages and convince the user of conspiracy theories.
#
# **<u>Week 9. Installing Geoserver: Part 1 of 2</u>**
#
# **Week 3 Homework Due**
#
# **Week 9 Homework: GeoServer**
#
# <i>Grading Scale:</i>
#
# 0. Did not attempt.
# 1. Installed GeoServer
#
# **Homework Notes**
#
# >- Navigate to the "webapps" folder within your tomcat installation with this command:

# %%
cd /var/lib/tomcat9/webapps

# %% [markdown]
# >- Download the latest Geoserver zip from their website:

# %%
sudo wget <url_path_to/geoserver-version.x-latest-bin.zip>

# %% [markdown]
# >- Install the 'unzip' utility if it is not already installed or use the file manager to unzip the downloaded GeoServer files:

# %%
sudo apt install unzip

# %% [markdown]
# - Move the files to the webapps directory and unzip the package:

# %%
sudo unzip /var/lib/tomcat9/webapps/geoserver-version.x-latest-bin.zip
sudo mv /User/Downloads/geoserver-version.x-latest-bin.zip /var/lib/tomcat9/webapps/

# %% [markdown]
# >- Make the .war executable for the current user by entering:

# %%
sudo chmod u+x /var/lib/tomcat9/webapps/geoserver.war

# %% [markdown]
# >- Start Geoserver:

# %%
cd /var/lib/tomcat9/webapps/geoserver/bin/
sh startup.sh

# %% [markdown]
# >- Restart Tomcat:

# %%
sudo service tomcat9 restart

# %% [markdown]
# >- Point your browser at the following address:
# http://localhost:8080/geoserver/web/
#
# >- The default behavior of Geoserver is to set user to “admin” and password to “geoserver” but you can change it either in the web application GUI or in the appropriate configuration XML.
#
# **<u>Week 10. Installing Geoserver: Part 2 of 2</u>**
#
# >**Week 9 Homework Reminder**
#
# **<u>Week 11. Tomcat9 for ImageMosaic Plugin: Part 1 of 2</u>**
#
# >**Week 9 Homework Due**
#
# **Week 11 Homework: ImageMosaic**
#
# <i>Grading Scale:</i>
#
# 0. Did not attempt.
# 1. Installed ImageMosaic Plugin
#
# >- The servlet container (tomcat9) has to be modified to allow time series data to be uploaded onto Geoserver. Navigate to the following directory:

# %%
cd /usr/share/tomcat9/bin/

# %% [markdown]
# >- Enter this command to see the current Java parameters on the container:

# %%
ps aux | grep java

# %% [markdown]
# >- Make a BASH file:

# %%
sudo nano setenv.sh

# %% [markdown]
# >- Add the following Java methods to this file:

# %%
export JAVA_OPTS="$JAVA_OPTS -Duser.timezone=GMT"
export JAVA_OPTS="$JAVA_OPTS -Dorg.geotools.shapefile.datetime=true"

# %% [markdown]
# >- Save and exit the file. Run the script:

# %%
sh /setenv.sh

# %% [markdown]
# >- Restart Tomcat:

# %%
sudo service tomcat9 restart

# %% [markdown]
# >- Check to see if the JAVA_OPTS variables were applied:

# %%
ps aux | grep java

# %% [markdown]
# **<u> Week 12. Tomcat9 for ImageMosaic Plugin: Part 2 of 2</u>**
#
# >**Week 11 Homework Reminder**
#
# **<u>Week 13. GeoServer Time Series Configuration: Part 1 of 2</u>**
#
# **Week 11 Homework Due**
#
# **Week 13 Homework: Configuring GeoServer**
#
# <i>Grading Scale:</i>
#
# 0. Did not attempt.
# 1. Configured GeoServer.
#
# >- Configure the GeoServer installation to allow the upload of a time series raster dataset of your choice using the Image Mosaic plugin.
#
# >- Example rasters can be downloaded from the USGS Earth Explorer web application. You may need to use QGIS, ArcMap, or Python to clip the files or downsample the images to make them smaller.
#
# >- After downloading the data onto your Linux, change permissions on the folder to upload the files. Navigate to the "data" folder and make a directory to host the files:

# %%
cd /var/lib/tomcat9/webapps/geoserver/data/data
sudo mkdir timeseries
cd timeseries

# %% [markdown]
# - The two .properties files look like this:
#
# 'timeregex.properties'

# %%
regex=[0-9]{8}

# %% [markdown]
# 'indexer.properties'

# %%
TimeAttribute=ingestion
ElevationAttribute=elevation
Schema=*the_geom:Polygon,location:String,ingestion:java.util.Date,elevation:Integer
PropertyCollectors=TimestampFileNameExtractorSPI[timeregex](ingestion)

# %% [markdown]
# - Change permissions on the last /data/ folder to recursively give the user read and write access to all the files:

# %%
sudo chmod -R u+rw /var/lib/tomcat9/webapps/geoserver/data/data/timeseries

# %% [markdown]
# >- To upload the rasters, go to the web application in your browser.
# >- Under "Data" on the left hand side of the screen go to "Stores".
# >- Select "Add new stores".
# >- Select "ImageMosaic" and "Browse". Navigate to the folder you put the data in (data/timeseries)
# >- Select "OK".
#
# >- Fill out "Data Source Name" and "Description" then save.
#
# >- Click "Publish" on the next screen.
# >- Click "Dimensions" and enable "Time”. “Presentation"
# should be set to "List".
#
# >- Then select "Save".
#
# If it worked, you can go to "Layer Preview" and click "timeseries" and view the tiffs as a Web Map Services (WMS).
#
# **<u>Week 14. Geoserver Time Series Configuration: Part 2 of 2</u>**
#
# >**Week 13 Homework Reminder**
#
# **<u> Week 15. Web Map Services</u>**
#
# **Week 13 Homework Due**
#
# **Week 15 Homework: Website Development**
#
# <i>Grading Scale:</i>
#
# 0. Did not attempt.
# 1. Wrote an application to view the tiffs.
#
# **Notes**
#
# >- Environmental Systems Research Institute (ESRI) is a developer for GIS software such as ArcMap along with the replacement desktop application ArcPro and commands most of the market share by licensing to governments and private companies.
#
# >- OpenLayers is an open source web development library with numerous features that are similar to ESRI's proprietary JavaScript library.
#
# >>- Open source software has almost no licensing or warranties about mathematical accuracy and reliability. These are usually free and are written by hobbyists and educational instructors that enjoy programming.
#
# >>- Proprietary software is developed by private or public organizations that charge money to ensure their products have a standard of accuracy and support.
#
# **Homework Notes**
#
# >- This week a website will be developed to view the WMS as a time slider in a browser.
#
# >- Modify HTML/CSS/JS by navigating to the www folder:

# %%
cd /var/lib/tomcat8/webapps/geoserver/data/www

# %% [markdown]
# >- Create a file name "rasterTime.html"

# %%
sudo nano rasterTime.html

# %% [markdown]
# >- The HTML file references two files from OpenLayers that give access to numerous CSS and JavaScript (JS) methods. Copy this text into the file:

# %%
<!DOCTYPE html>
<html>
  <head>
  <title>WMS Time</title>
  <link rel="stylesheet" href="https://openlayers.org/en/v4.6.5/css/ol.css" type="text/css">
  <script src="https://openlayers.org/en/v4.6.5/build/ol.js"></script>

# %% [markdown]
# >- CSS is added for styling the HTML. This can be included as a seperate CSS file with markdown similar to the OpenLayers references:

# %%
  <style>
    /* Slider styling */
    .slidecontainer {
      width: 120px;
      margin-top: -30px;
      margin-left: 10px;
      z-index: 100px;
    }
    .slider {
      -webkit-appearance: none;
      width: 100%;
      height: 15px;
      border-radius: 5px;
      background: #d3d3d3;
      outline: none;
      opacity: 0.7;
      -webkit-transition: .2s;
      transition: opacity .2s;
    }
    .slider::-webkit-slider-thumb {
      -webkit-appearance: none;
      appearance: none;
      width: 25px;
      height: 25px;
      border-radius: 50%;
      background: #00008B;
      cursor: pointer;
    }
    .slider::-moz-range-thumb {
      width: 25px;
      height: 25px;
      border-radius: 50%;
      background: #4CAF50;
      cursor: pointer;
    }
  </style>
  </head>

# %% [markdown]
# >- Markdown is included to create a div containing the map and a div containing the time slider button:

# %%
  <body>
    <!-- Create map container -->
    <div id="map" class="map"></div>
    <div role="group" aria-label="Animation controls">
    <!-- Create slider container -->
    <div class="slidecontainer">
    <input type="range" min="0" max="2" value="0" class="slider" id="myRange">
    <p>Date: <span id="date_value"></span></p>
    </div>

# %% [markdown]
# >- The JavaScript functions from OpenLayers external library defined above in the < head > tags are used here within user defined < script > tags as 'ol'.
# >- The first user function refers to a basemap tiling service hosted by OpenStreetMap (OSM) and the second is the user defined tile WMS hosted on GeoServer transforming the file into the Web Mercator projection at the specific latitude and longitude.
# >- The next three functions draw the timeslider referring to each tile service using the first ten characters of the date and time.

# %%
  <script>
  // Set up the layers
  var layers = [
    new ol.layer.Tile({
    source: new ol.source.OSM()
    }),
    new ol.layer.Tile({
      source: new ol.source.TileWMS({
      url: 'http://xx.XXX.XXX.XXX:8080/geoserver/cite/wms',
      params: {'LAYERS': 'cite:timeseries'}
      })
    })
  ];
  var map = new ol.Map({
    layers: layers,
    target: 'map',
    view: new ol.View({
      // Defining the location in Lat Lon.
      center: ol.proj.transform(
          [-120.5542,43.8041], 'EPSG:4326', 'EPSG:3857'),
      zoom: 5
    })
  });
  // Define the available dates
  var dates = ['1981-01-01T00:00:00.000Z', '1991-01-01T00:00:00.000Z',
'2001-01-01T00:00:00.000Z', '2011-01-01T00:00:00.000Z']
  var sliderRange = document.getElementById("myRange");
  sliderRange.max = dates.length-1;
  var dateValue = document.getElementById("date_value");
  dateValue.innerHTML = dates[sliderRange.value].slice(0,10);
  layers[1].getSource().updateParams({'TIME': dates[sliderRange.value]});
  // Update the current slider value (each time you drag the slider handle)
  sliderRange.oninput = function() {
  dateValue.innerHTML = dates[this.value].slice(0,10);
  layers[1].getSource().updateParams({'TIME': dates[this.value]});
}
</script>
</body>
</html>

# %% [markdown]
# >- The OpenLayers documentation and StackOverflow websites have several examples to answer any questions.
#
# **<u> Week 16. Review for Final</u>**
#
# >**Week 15 Homework Due**
#
# **<u> Week 17. Final</u>**
